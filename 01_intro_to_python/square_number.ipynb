# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/Python-Panaversity-Homework-Projects/blob/main/square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**
# Ask the user for a number and print its square (the product of the number times itself).
#
# Here's a sample run of the program (user input is in bold italics):
#
# Type a number to see its square: 4
#
# 4.0 squared is 16.0

# %%
# Print Name Statement
print("This project calculates sqaure of any number\n")

# Input Number
number : float = float(input("Type a number to see its square: "))

# Calculating Square
square : float = number * number

# Printing Square
print(f"\n{number} squared is {square}")
# Out:
# This project calculates sqaure of any number
#
# Type a number to see its square: 4
#
# 4.0 squared is 16.0
