# %% [markdown]
# ## **Problem Statement**
# Ask the user for a number and print its square (the product of the number times itself).
#
# Here's a sample run of the program (user input is in bold italics):
#
# Type a number to see its square: 4
#
# 4.0 squared is 16.0

# %%
def main(): # Main Function
    # Print Name Statement
    print("This project calculates sqaure of any number\n")

    # Input Number
    number : float = float(input("Type a number to see its square: "))

    # Calculating Square
    square : float = number * number # or number ** 2 (Square formula = n^2 or num*num)

    # Printing Square
    print(f"\n{number} squared is {square}") # f-string for formatted output

# Run Main Function
if __name__ == "__main__": # Run Main
    main() # Call Main Function
# Out:
# This project calculates sqaure of any number
#
# Type a number to see its square: 4
#
# 4.0 squared is 16.0
