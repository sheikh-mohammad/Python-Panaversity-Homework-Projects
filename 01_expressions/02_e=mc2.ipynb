# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/python-panaversity-homework-projects/blob/main/01_expressions/02_e%3Dmc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**
#
# Write a program that continually reads in mass from the user and then outputs the equivalent energy using Einstein's mass-energy equivalence formula (E stands for energy, m stands for mass, and C is the speed of light:
#
# E = m * c**2
#
# Almost 100 years ago, Albert Einstein famously discovered that mass and energy are interchangeable and are related by the above equation. You should ask the user for mass (m) in kilograms and use a constant value for the speed of light -- C = 299792458 m/s.
#
# Here's a sample run of the program (user input is in bold italics):
#
# Enter kilos of mass: 100
#
# e = m * C^2...
#
# m = 100.0 kg
#
# C = 299792458 m/s
#
# 8.987551787368176e+18 joules of energy!

# %%
# Main function to calculate energy in joules
def main():
    # Input the Mass in kilos in float
    kilos_of_mass : float = float(input("Enter kilos of mass: "))
    # Constant Value of C (speed of light) in m/s
    C : int = 299792458
    # Calculating the energy in joules (Energy's SI Unit)
    energy_in_joules : float = kilos_of_mass * (C ** 2)

    # Showing the output to user
    print("e = m * C^2...")
    print(f"m = {kilos_of_mass} kg")
    print(f"C = {C} m/s")
    print(f"{energy_in_joules} joules of energy!")

# Entry point of the script
if __name__ == '__main__': # Check if the script is being run directly
    main() # Call the main function to start the program
# Out:
# Enter kilos of mass: 100
# e = m * C^2...
# m = 100.0 kg
# C = 299792458 m/s
# 8.987551787368176e+18 joules of energy!
