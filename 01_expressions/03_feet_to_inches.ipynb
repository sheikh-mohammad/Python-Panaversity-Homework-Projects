# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/python-panaversity-homework-projects/blob/main/01_expressions/03_feet_to_inches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem Statement**
#
# Converts feet to inches. Feet is an American unit of measurement. There are 12 inches per foot. Foot is the singular, and feet is the plural.

# %%
def main():
    FEET_IN_INCHES : int = 12

    feet : float = float(input("Enter number of feet: "))

    inches : float = feet * 12

    print(f"There is {inches} inches!")

if __name__ == '__main__':
    main()
